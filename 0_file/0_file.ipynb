# %%
#!pip install pylabel
#!pip install utils
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting utils
#   Downloading utils-1.0.1-py2.py3-none-any.whl (21 kB)
# Installing collected packages: utils
# Successfully installed utils-1.0.1

# %%
# import
import os
import sys
from PIL import Image
import time
import numpy as np
import random
from pylabel import importer
import glob, json, os, shutil
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from pprint import pprint
import glob, json
import torch
import utils
from glob import glob
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 0. 데이터 생성
# ---

# %%
file_list = os.listdir('./TrainingData/data/Images/')
img_random=random.sample(file_list, 100)
#img_random.save('./Dataset/', format='PNG')
img_random
# Out:
# ['V2F_HY_9153_20201105_150400_E_CH1_Seoul_Sun_Mainroad_Day_86595.png',
#  'V2F_HY_9285_20201103_132218_E_CH0_Seoul_Sun_Mainroad_Day_48651.png',
#  'V2F_HY_9289_20210111_104944_N_CH2_Seoul_Cloud_Mainroad_Day_79837.png',
#  'V2F_HY_9157_20201221_140714_E_CH0_Seoul_Sun_Mainroad_Day_90029.png',
#  'V2F_HY_9156_20201103_133318_E_CH0_Seoul_Sun_Mainroad_Day_84050.png',
#  'V2F_HY_9184_20210111_105430_E_CH1_Seoul_Cloud_Mainroad_Day_05412.png',
#  'V2F_HY_9148_20201221_121331_E_CH1_Seoul_Sun_Mainroad_Day_54826.png',
#  'V2F_HY_9191_20210111_110030_N_CH0_Seoul_Cloud_Mainroad_Day_53637.png',
#  'V2F_HY_9187_20201221_144144_E_CH0_Seoul_Sun_Mainroad_Day_84744.png',
#  'V2F_HY_9192_20201102_103254_E_CH1_Seoul_Sun_Mainroad_Day_97244.png',
#  'V2F_HY_9195_20210112_152251_E_CH1_Seoul_Snow_Mainroad_Day_00534.png',
#  'V2F_HY_9256_20210112_154027_N_CH1_Seoul_Snow_Mainroad_Day_76761.png',
#  'V2F_HY_9280_20210111_104844_N_CH1_Seoul_Cloud_Mainroad_Day_68382.png',
#  'V2F_HY_9202_20210111_105830_N_CH2_Seoul_Cloud_Mainroad_Day_41232.png',
#  'V2F_HY_9185_20201221_144044_N_CH2_Seoul_Sun_Mainroad_Day_65762.png',
#  'V2F_HY_9259_20201103_133618_E_CH0_Seoul_Sun_Mainroad_Day_39514.png',
#  'V2F_HY_9235_20201103_130817_E_CH0_Seoul_Sun_Mainroad_Day_64369.png',
#  'V2F_HY_9178_20201221_124054_E_CH1_Seoul_Sun_Mainroad_Day_01780.png',
#  'V2F_HY_9250_20201221_120931_N_CH0_Seoul_Sun_Mainroad_Day_44064.png',
#  'V2F_HY_9199_20210112_153528_N_CH1_Seoul_Snow_Mainroad_Day_88992.png',
#  'V2F_HY_9263_20201221_121331_E_CH1_Seoul_Sun_Mainroad_Day_02363.png',
#  'V2F_HY_9224_20201103_131118_E_CH0_Seoul_Sun_Mainroad_Day_07705.png',
#  'V2F_HY_9250_20201105_143600_N_CH2_Seoul_Sun_Mainroad_Day_67237.png',
#  'V2F_HY_9256_20201221_120931_E_CH0_Seoul_Sun_Mainroad_Day_70122.png',
#  'V2F_HY_9281_20201102_081131_E_CH1_Seoul_Sun_Mainroad_Day_60213.png',
#  'V2F_HY_9148_20201221_111302_E_CH0_Seoul_Sun_Mainroad_Day_97331.png',
#  'V2F_HY_9182_20201221_140714_N_CH2_Seoul_Sun_Mainroad_Day_13798.png',
#  'V2F_HY_9206_20201221_140914_E_CH1_Seoul_Sun_Mainroad_Day_76939.png',
#  'V2F_HY_9219_20210111_104327_N_CH1_Seoul_Cloud_Mainroad_Day_15840.png',
#  'V2F_HY_9224_20201221_144744_N_CH0_Seoul_Sun_Mainroad_Day_58054.png',
#  'V2F_HY_9197_20210111_110030_N_CH2_Seoul_Cloud_Mainroad_Day_35440.png',
#  'V2F_HY_9183_20201103_133318_E_CH0_Seoul_Sun_Mainroad_Day_78798.png',
#  'V2F_HY_9147_20201102_081931_E_CH0_Seoul_Sun_Mainroad_Day_72590.png',
#  'V2F_HY_9233_20201030_182234_N_CH0_Seoul_Sun_Mainroad_Night_94289.png',
#  'V2F_HY_9213_20210112_152603_N_CH2_Seoul_Snow_Mainroad_Day_84108.png',
#  'V2F_HY_9289_20201103_124453_N_CH2_Seoul_Sun_Mainroad_Day_60189.png',
#  'V2F_HY_9244_20201102_081931_E_CH0_Seoul_Sun_Mainroad_Day_80667.png',
#  'V2F_HY_9274_20201221_120931_N_CH1_Seoul_Sun_Mainroad_Day_20012.png',
#  'V2F_HY_9231_20201221_124054_E_CH0_Seoul_Sun_Mainroad_Day_94598.png',
#  'V2F_HY_9240_20201221_111302_E_CH0_Seoul_Sun_Mainroad_Day_88815.png']

# %% [markdown]
# # 1. 데이터 전처리
# ## 1-1) Image Compression
# ---

# %%
def change_img_qualty(original_path, change_path, qualty):
    """
    Change Image Qualty
    :param original_path: 원본 경로
    :param change_path: 변경 후 새롭게 저장될 경로
    :param qualty: Qualty(품질) 퍼센트(기본 : 85%)
    :return:
    """
    if not os.path.exists(change_path):
        os.mkdir(change_path)
    try:
        ims_list = os.listdir(original_path)
        ims_list.sort()
    except FileNotFoundError as e:
        print("이미지 원본 디렉터리가 존재하지 않습니다...")
        sys.exit(0)
    success_cnt = 0
    fail_cnt = 0
    for filename in ims_list:
        file = original_path + filename
        try:
            im = Image.open(file)
            im.save(os.path.join(change_path, filename), qualty=qualty)
            print("+ 성공 : {success}\n  "
                  "- {success_path}"
                  .format(success=file, success_path=os.path.join(change_path, filename))
                  )
            success_cnt += 1
        except Exception as e:
            print("+ 실패 : {fail}".format(fail=file))
            fail_cnt += 1
    print("\n성공 : {success_cnt} 건 / 실패 : {fail_cnt} 건".format(success_cnt=success_cnt, fail_cnt=fail_cnt))
    sys.exit(0)

# %%
if __name__ == '__main__':
    original_path = './TrainingData/data/Images/'
    change_path = './TrainingData/data/change_img/'
    change_img_qualty(original_path, change_path,85)
# Out:
# + 성공 : ./TrainingData/data/Images/V2F_HY_9147_20201102_081931_E_CH0_Seoul_Sun_Mainroad_Day_72590.png
#   - ./TrainingData/data/change_img/V2F_HY_9147_20201102_081931_E_CH0_Seoul_Sun_Mainroad_Day_72590.png
# + 성공 : ./TrainingData/data/Images/V2F_HY_9286_20201221_124054_N_CH2_Seoul_Sun_Mainroad_Day_10366.png
#   - ./TrainingData/data/change_img/V2F_HY_9286_20201221_124054_N_CH2_Seoul_Sun_Mainroad_Day_10366.png
# + 성공 : ./TrainingData/data/Images/V2F_HY_9287_20201221_111302_E_CH0_Seoul_Sun_Mainroad_Day_81019.png
#   - ./TrainingData/data/change_img/V2F_HY_9287_20201221_111302_E_CH0_Seoul_Sun_Mainroad_Day_81019.png
# + 성공 : ./TrainingData/data/Images/V2F_HY_9289_20201103_124453_N_CH2_Seoul_Sun_Mainroad_Day_60189.png
#   - ./TrainingData/data/change_img/V2F_HY_9289_20201103_124453_N_CH2_Seoul_Sun_Mainroad_Day_60189.png
# + 성공 : ./TrainingData/data/Images/V2F_HY_9289_20201221_141515_N_CH0_Seoul_Sun_Mainroad_Day_13404.png
#   - ./TrainingData/data/change_img/V2F_HY_9289_20201221_141515_N_CH0_Seoul_Sun_Mainroad_Day_13404.png
# + 성공 : ./TrainingData/data/Images/V2F_HY_9289_20210111_104944_N_CH2_Seoul_Cloud_Mainroad_Day_79837.png
#   - ./TrainingData/data/change_img/V2F_HY_9289_20210111_104944_N_CH2_Seoul_Cloud_Mainroad_Day_79837.png
#
# 성공 : 100 건 / 실패 : 0 건
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3406: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ## 1-2) Category Equalization
# ## 1-3) Convert COCO to YOLO
# ## 1-4) Convert json to txt
# ---

# %%
# annotation 폴더 내의 json 파일 불러오기
LABEL_PATH = './TrainingData/data/Annotations/'
IMAGE_PATH = './TrainingData/data/Images/'
LABEL_SAVE_PATH = './TrainingData/data/equalized_label'
IMAGE_SAVE_PATH = './TrainingData/data/equalized_img'
json_list = os.listdir(LABEL_PATH)
img_list = os.listdir(IMAGE_PATH)

# %%
cat_1 = 0  # Animals(Dolls)                                    delete
cat_2 = 0  # Person
cat_3 = 0  # Garbage bag & sacks
cat_4 = 0  # Construction signs & Parking prohibited board
cat_5 = 0  # Traffic cone
cat_6 = 0  # Box                                               delete
cat_7 = 0  # Stones on road                                    delete
cat_8 = 0  # Pothole on road
cat_9 = 0  # Filled pothole
cat_10 = 0  # Manhole
cat_list = ["Animals(Dolls)", "Person", "Garbage bag & sacks", "Construction signs & Parking prohibited board",
            "Traffic cone",
            "Box", "Stones on road", "Pothole on road", "Filled pothole", "Manhole"]

# %%
for file in json_list:
    # pylabel load
    dataset = importer.ImportCoco(LABEL_PATH + file)

    for i in range(len(dataset.df)):
        # if 라벨이 하나만 있을 때
        if len(dataset.df) == 1:
            # 이미지 복사를 위한 변수들
            cat_id = dataset.df.iloc[i].cat_id
            img_name = dataset.df.iloc[i].img_filename

            # txt 변경을 위한 변수들
            img_name2 = dataset.df.iloc[i].img_filename[:-3]
            bbox_x = dataset.df.iloc[i].ann_bbox_xmin
            bbox_y = dataset.df.iloc[i].ann_bbox_ymin
            height = dataset.df.iloc[i].ann_bbox_height
            width = dataset.df.iloc[i].ann_bbox_width
            img_height = dataset.df.iloc[i].img_height
            img_width = dataset.df.iloc[i].img_width
            img_category = int(dataset.df.iloc[i].cat_id) - 1

            if int(cat_id) == 2 and cat_2 <= 100:
                # ------------------- 이미지 복사 부분 -------------------
                # 폴더가 없으면 폴더 생성
                if not os.path.exists(IMAGE_SAVE_PATH + cat_id):
                    os.makedirs(IMAGE_SAVE_PATH + cat_id)
                else:
                    pass
                # 파일을 새로운 경로로 복사한다.
                shutil.copy2(IMAGE_PATH + img_name, IMAGE_SAVE_PATH + cat_id + '/' + img_name)
                # ------------------------------------------------------

                # -------------------- 라벨 생성 부분 --------------------
                if img_height == 0:
                    img_height = 720
                else:
                    pass
                if img_width == 0:
                    img_width = 1280
                else:
                    pass

                dw = 1.0 / img_width
                dh = 1.0 / img_height

                x_center = bbox_x + width / 2.0
                y_center = bbox_y + height / 2.0

                x = x_center * dw
                y = y_center * dh
                w = width * dw
                h = height * dh
                # 폴더가 없으면 폴더 생성
                if not os.path.exists(LABEL_SAVE_PATH + cat_id):
                    os.makedirs(LABEL_SAVE_PATH + cat_id)
                else:
                    pass

                # 파일이 있으면
                if os.path.isfile(LABEL_SAVE_PATH + cat_id + '/' + img_name2 + 'txt'):
                    pass
                # 파일이 없으면
                else:
                    f = open(LABEL_SAVE_PATH + cat_id + '/' + img_name2 + 'txt', 'w')
                    f.close()

                f = open(LABEL_SAVE_PATH + cat_id + '/' + img_name2 + 'txt', 'a')
                f.write(str(img_category) + ' ')
                f.write(str(x) + ' ')
                f.write(str(y) + ' ')
                f.write(str(w) + ' ')
                f.write(str(h) + '\n')
                f.close()
                # ------------------------------------------------------

                # 카테고리 카운팅
                cat_2 += 1

            if int(cat_id) == 3 and cat_3 <= 100:
                # ------------------- 이미지 복사 부분 -------------------
                # 폴더가 없으면 폴더 생성
                if not os.path.exists(IMAGE_SAVE_PATH + cat_id):
                    os.makedirs(IMAGE_SAVE_PATH + cat_id)
                else:
                    pass
                # 파일을 새로운 경로로 복사한다.
                shutil.copy2(IMAGE_PATH + img_name, IMAGE_SAVE_PATH + cat_id + '/' + img_name)
                # ------------------------------------------------------

                # -------------------- 라벨 생성 부분 --------------------
                if img_height == 0:
                    img_height = 720
                else:
                    pass
                if img_width == 0:
                    img_width = 1280
                else:
                    pass

                dw = 1.0 / img_width
                dh = 1.0 / img_height

                x_center = bbox_x + width / 2.0
                y_center = bbox_y + height / 2.0

                x = x_center * dw
                y = y_center * dh
                w = width * dw
                h = height * dh
                # 폴더가 없으면 폴더 생성
                if not os.path.exists(LABEL_SAVE_PATH + cat_id):
                    os.makedirs(LABEL_SAVE_PATH + cat_id)
                else:
                    pass

                # 파일이 있으면
                if os.path.isfile(LABEL_SAVE_PATH + cat_id + '/' + img_name2 + 'txt'):
                    pass
                # 파일이 없으면
                else:
                    f = open(LABEL_SAVE_PATH + cat_id + '/' + img_name2 + 'txt', 'w')
                    f.close()

                f = open(LABEL_SAVE_PATH + cat_id + '/' + img_name2 + 'txt', 'a')
                f.write(str(img_category) + ' ')
                f.write(str(x) + ' ')
                f.write(str(y) + ' ')
                f.write(str(w) + ' ')
                f.write(str(h) + '\n')
                f.close()
                # ------------------------------------------------------
                # 카테고리 카운팅
                cat_3 += 1
            if int(cat_id) == 4 and cat_4 <= 100:
                # ------------------- 이미지 복사 부분 -------------------
                # 폴더가 없으면 폴더 생성
                if not os.path.exists(IMAGE_SAVE_PATH + cat_id):
                    os.makedirs(IMAGE_SAVE_PATH + cat_id)
                else:
                    pass
                # 파일을 새로운 경로로 복사한다.
                shutil.copy2(IMAGE_PATH + img_name, IMAGE_SAVE_PATH + cat_id + '/' + img_name)
                # ------------------------------------------------------

                # -------------------- 라벨 생성 부분 --------------------
                if img_height == 0:
                    img_height = 720
                else:
                    pass
                if img_width == 0:
                    img_width = 1280
                else:
                    pass

                dw = 1.0 / img_width
                dh = 1.0 / img_height

                x_center = bbox_x + width / 2.0
                y_center = bbox_y + height / 2.0

                x = x_center * dw
                y = y_center * dh
                w = width * dw
                h = height * dh
                # 폴더가 없으면 폴더 생성
                if not os.path.exists(LABEL_SAVE_PATH + cat_id):
                    os.makedirs(LABEL_SAVE_PATH + cat_id)
                else:
                    pass

                # 파일이 있으면
                if os.path.isfile(LABEL_SAVE_PATH + cat_id + '/' + img_name2 + 'txt'):
                    pass
                # 파일이 없으면
                else:
                    f = open(LABEL_SAVE_PATH + cat_id + '/' + img_name2 + 'txt', 'w')
                    f.close()

                f = open(LABEL_SAVE_PATH + cat_id + '/' + img_name2 + 'txt', 'a')
                f.write(str(img_category) + ' ')
                f.write(str(x) + ' ')
                f.write(str(y) + ' ')
                f.write(str(w) + ' ')
                f.write(str(h) + '\n')
                f.close()
                # ------------------------------------------------------
                # 카테고리 카운팅
                cat_4 += 1
            if int(cat_id) == 5 and cat_5 <= 100:
                # ------------------- 이미지 복사 부분 -------------------
                # 폴더가 없으면 폴더 생성
                if not os.path.exists(IMAGE_SAVE_PATH + cat_id):
                    os.makedirs(IMAGE_SAVE_PATH + cat_id)
                else:
                    pass
                # 파일을 새로운 경로로 복사한다.
                shutil.copy2(IMAGE_PATH + img_name, IMAGE_SAVE_PATH + cat_id + '/' + img_name)
                # ------------------------------------------------------

                # -------------------- 라벨 생성 부분 --------------------
                if img_height == 0:
                    img_height = 720
                else:
                    pass
                if img_width == 0:
                    img_width = 1280
                else:
                    pass

                dw = 1.0 / img_width
                dh = 1.0 / img_height

                x_center = bbox_x + width / 2.0
                y_center = bbox_y + height / 2.0

                x = x_center * dw
                y = y_center * dh
                w = width * dw
                h = height * dh
                # 폴더가 없으면 폴더 생성
                if not os.path.exists(LABEL_SAVE_PATH + cat_id):
                    os.makedirs(LABEL_SAVE_PATH + cat_id)
                else:
                    pass

                # 파일이 있으면
                if os.path.isfile(LABEL_SAVE_PATH + cat_id + '/' + img_name2 + 'txt'):
                    pass
                # 파일이 없으면
                else:
                    f = open(LABEL_SAVE_PATH + cat_id + '/' + img_name2 + 'txt', 'w')
                    f.close()

                f = open(LABEL_SAVE_PATH + cat_id + '/' + img_name2 + 'txt', 'a')
                f.write(str(img_category) + ' ')
                f.write(str(x) + ' ')
                f.write(str(y) + ' ')
                f.write(str(w) + ' ')
                f.write(str(h) + '\n')
                f.close()
                # ------------------------------------------------------
                # 카테고리 카운팅
                cat_5 += 1
            if int(cat_id) == 8 and cat_8 <= 100:
                # ------------------- 이미지 복사 부분 -------------------
                # 폴더가 없으면 폴더 생성
                if not os.path.exists(IMAGE_SAVE_PATH + cat_id):
                    os.makedirs(IMAGE_SAVE_PATH + cat_id)
                else:
                    pass
                # 파일을 새로운 경로로 복사한다.
                shutil.copy2(IMAGE_PATH + img_name, IMAGE_SAVE_PATH + cat_id + '/' + img_name)
                # ------------------------------------------------------

                # -------------------- 라벨 생성 부분 --------------------
                if img_height == 0:
                    img_height = 720
                else:
                    pass
                if img_width == 0:
                    img_width = 1280
                else:
                    pass

                dw = 1.0 / img_width
                dh = 1.0 / img_height

                x_center = bbox_x + width / 2.0
                y_center = bbox_y + height / 2.0

                x = x_center * dw
                y = y_center * dh
                w = width * dw
                h = height * dh
                # 폴더가 없으면 폴더 생성
                if not os.path.exists(LABEL_SAVE_PATH + cat_id):
                    os.makedirs(LABEL_SAVE_PATH + cat_id)
                else:
                    pass

                # 파일이 있으면
                if os.path.isfile(LABEL_SAVE_PATH + cat_id + '/' + img_name2 + 'txt'):
                    pass
                # 파일이 없으면
                else:
                    f = open(LABEL_SAVE_PATH + cat_id + '/' + img_name2 + 'txt', 'w')
                    f.close()

                f = open(LABEL_SAVE_PATH + cat_id + '/' + img_name2 + 'txt', 'a')
                f.write(str(img_category) + ' ')
                f.write(str(x) + ' ')
                f.write(str(y) + ' ')
                f.write(str(w) + ' ')
                f.write(str(h) + '\n')
                f.close()
                # ------------------------------------------------------
                # 카테고리 카운팅
                cat_8 += 1
            if int(cat_id) == 9 and cat_9 <= 100:
                # ------------------- 이미지 복사 부분 -------------------
                # 폴더가 없으면 폴더 생성
                if not os.path.exists(IMAGE_SAVE_PATH + cat_id):
                    os.makedirs(IMAGE_SAVE_PATH + cat_id)
                else:
                    pass
                # 파일을 새로운 경로로 복사한다.
                shutil.copy2(IMAGE_PATH + img_name, IMAGE_SAVE_PATH + cat_id + '/' + img_name)
                # ------------------------------------------------------

                # -------------------- 라벨 생성 부분 --------------------
                if img_height == 0:
                    img_height = 720
                else:
                    pass
                if img_width == 0:
                    img_width = 1280
                else:
                    pass

                dw = 1.0 / img_width
                dh = 1.0 / img_height

                x_center = bbox_x + width / 2.0
                y_center = bbox_y + height / 2.0

                x = x_center * dw
                y = y_center * dh
                w = width * dw
                h = height * dh
                # 폴더가 없으면 폴더 생성
                if not os.path.exists(LABEL_SAVE_PATH + cat_id):
                    os.makedirs(LABEL_SAVE_PATH + cat_id)
                else:
                    pass

                # 파일이 있으면
                if os.path.isfile(LABEL_SAVE_PATH + cat_id + '/' + img_name2 + 'txt'):
                    pass
                # 파일이 없으면
                else:
                    f = open(LABEL_SAVE_PATH + cat_id + '/' + img_name2 + 'txt', 'w')
                    f.close()

                f = open(LABEL_SAVE_PATH + cat_id + '/' + img_name2 + 'txt', 'a')
                f.write(str(img_category) + ' ')
                f.write(str(x) + ' ')
                f.write(str(y) + ' ')
                f.write(str(w) + ' ')
                f.write(str(h) + '\n')
                f.close()
                # ------------------------------------------------------
                # 카테고리 카운팅
                cat_9 += 1
            if int(cat_id) == 10 and cat_10 <= 100:
                # ------------------- 이미지 복사 부분 -------------------
                # 폴더가 없으면 폴더 생성
                if not os.path.exists(IMAGE_SAVE_PATH + cat_id):
                    os.makedirs(IMAGE_SAVE_PATH + cat_id)
                else:
                    pass
                # 파일을 새로운 경로로 복사한다.
                shutil.copy2(IMAGE_PATH + img_name, IMAGE_SAVE_PATH + cat_id + '/' + img_name)
                # ------------------------------------------------------

                # -------------------- 라벨 생성 부분 --------------------
                if img_height == 0:
                    img_height = 720
                else:
                    pass
                if img_width == 0:
                    img_width = 1280
                else:
                    pass

                dw = 1.0 / img_width
                dh = 1.0 / img_height

                x_center = bbox_x + width / 2.0
                y_center = bbox_y + height / 2.0

                x = x_center * dw
                y = y_center * dh
                w = width * dw
                h = height * dh
                # 폴더가 없으면 폴더 생성
                if not os.path.exists(LABEL_SAVE_PATH + cat_id):
                    os.makedirs(LABEL_SAVE_PATH + cat_id)
                else:
                    pass

                # 파일이 있으면
                if os.path.isfile(LABEL_SAVE_PATH + cat_id + '/' + img_name2 + 'txt'):
                    pass
                # 파일이 없으면
                else:
                    f = open(LABEL_SAVE_PATH + cat_id + '/' + img_name2 + 'txt', 'w')
                    f.close()

                f = open(LABEL_SAVE_PATH + cat_id + '/' + img_name2 + 'txt', 'a')
                f.write(str(img_category) + ' ')
                f.write(str(x) + ' ')
                f.write(str(y) + ' ')
                f.write(str(w) + ' ')
                f.write(str(h) + '\n')
                f.close()
                # ------------------------------------------------------
                # 카테고리 카운팅
                cat_10 += 1
        else:
            pass

# %%
cat_count = [cat_1, cat_2, cat_3, cat_4, cat_5,
             cat_6, cat_7, cat_8, cat_9, cat_10]

# %%
plt.title("Category Status", size=20)
plt.bar(cat_list, cat_count, color=mcolors.TABLEAU_COLORS)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # 2. Create yaml
# ---

# %%
# 이미지 파일 리스트 생성
train_img_list = glob(r'./TrainingData/data/change_img/*.png')
print(f'Image 갯수: {len(train_img_list)}')
# Out:
# Image 갯수: 100

# %%
# train, validation 데이터 분리
train_img_list, val_img_list = train_test_split(train_img_list,
                                                  train_size=0.8,
                                                  random_state=42)

print(f'Train Image 갯수: {len(train_img_list)}')
print(f'Validation Image 갯수: {len(val_img_list)}')
# Out:
# Train Image 갯수: 80
# Validation Image 갯수: 20

# %%
# train/val 이미지 경로 txt파일로 저장
with open(r'C:\Users\USER\T3Q_1_project\TrainingData\train.txt', 'w') as f:
    f.write('\n'.join(train_img_list) + '\n')

with open(r'C:\Users\USER\T3Q_1_project\TrainingData\val.txt', 'w') as f:
    f.write('\n'.join(val_img_list) + '\n')

# %%
# ymal 파일 정보 확인
import yaml

with open(r'C:\Users\USER\T3Q_1_project\TrainingData\data.yaml', 'r') as f:
    data = yaml.full_load(f)

print(f'data.yaml 파일 정보: {data}')

data['train'] = r'C:\Users\USER\T3Q_1_project\TrainingData\train.txt'
data['val'] = r'C:\Users\USER\T3Q_1_project\TrainingData\val.txt'

with open(r'C:\Users\USER\T3Q_1_project\TrainingData\data.yaml', 'w') as f:
    yaml.dump(data, f)

print(data)
# Out:
# data.yaml 파일 정보: {'names': ['Animals(Dolls)', 'Person', 'Garbage bag & sacks', 'Construction signs & Parking prohibited board', 'Traffic cone', 'Box', 'Stones on road', 'Pothole on road', 'Filled pothole', 'Manhole'], 'nc': 10, 'train': 'C:\\Users\\USER\\T3Q_model\\data\\train.txt', 'val': 'C:\\Users\\USER\\T3Q_model\\data\\val.txt'}
# {'names': ['Animals(Dolls)', 'Person', 'Garbage bag & sacks', 'Construction signs & Parking prohibited board', 'Traffic cone', 'Box', 'Stones on road', 'Pothole on road', 'Filled pothole', 'Manhole'], 'nc': 10, 'train': 'C:\\Users\\USER\\T3Q_1_project\\TrainingData\\train.txt', 'val': 'C:\\Users\\USER\\T3Q_1_project\\TrainingData\\val.txt'}

# %% [markdown]
# # 3. YOLOv5
# ---

# %%
# !git clone https://github.com/knudatascientists/T3Q_projects_team_1/tree/main/yolo_v5/yolov5-master  # clone
# Out:
# fatal: Too many arguments.
#
# usage: git clone [<options>] [--] <repo> [<dir>]
#
#     -v, --verbose         be more verbose
#     -q, --quiet           be more quiet
#     --progress            force progress reporting
#     --reject-shallow      don't clone shallow repository
#     -n, --no-checkout     don't create a checkout
#     --bare                create a bare repository
#     --mirror              create a mirror repository (implies bare)
#     -l, --local           to clone from a local repository
#     --no-hardlinks        don't use local hardlinks, always copy
#     -s, --shared          setup as shared repository
#     --recurse-submodules[=<pathspec>]
#                           initialize submodules in the clone
#     --recursive ...       alias of --recurse-submodules
#     -j, --jobs <n>        number of submodules cloned in parallel
#     --template <template-directory>
#                           directory from which templates will be used
#     --reference <repo>    reference repository
#     --reference-if-able <repo>
#                           reference repository
#     --dissociate          use --reference only while cloning
#     -o, --origin <name>   use <name> instead of 'origin' to track upstream
#     -b, --branch <branch>
#                           checkout <branch> instead of the remote's HEAD
#     -u, --upload-pack <path>
#                           path to git-upload-pack on the remote
#     --depth <depth>       create a shallow clone of that depth
#     --shallow-since <time>
#                           create a shallow clone since a specific time
#     --shallow-exclude <revision>
#                           deepen history of shallow clone, excluding rev
#     --single-branch       clone only one branch, HEAD or --branch
#     --no-tags             don't clone any tags, and make later fetches not to follow them
#     --shallow-submodules  any cloned submodules will be shallow
#     --separate-git-dir <gitdir>
#                           separate git dir from working tree
#     -c, --config <key=value>
#                           set config inside the new repository
#     --server-option <server-specific>
#                           option to transmit
#     -4, --ipv4            use IPv4 addresses only
#     -6, --ipv6            use IPv6 addresses only
#     --filter <args>       object filtering
#     --also-filter-submodules
#                           apply partial clone filters to submodules
#     --remote-submodules   any cloned submodules will use their remote-tracking branch
#     --sparse              initialize sparse-checkout file to include only files at root
#     --bundle-uri <uri>    a URI for downloading bundles before fetching from origin remote

# %%
# %cd C://project/T3Q_projects_team_1/yolo_v5/yolov5-master
# Out:
# C:\project\T3Q_projects_team_1\yolo_v5\yolov5-master

# %%
#%pip install -qr requirements.txt

# %%
# !python train.py --batch 16 --epochs 50 --data C://Users/USER/T3Q_1_project/TrainingData/data.yaml  --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name T3Q_yolov5s_results
# Out:
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# 'cp949' codec can't decode byte 0xf0 in position 9: illegal multibyte sequence
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=C://Users/USER/T3Q_1_project/TrainingData/data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=T3Q_yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5  2022-11-27 Python-3.9.13 torch-1.13.0+cpu CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5  in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5  runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs\train', view at http://localhost:6006/
# 2022-11-28 13:43:34.737975: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-11-28 13:43:34.738318: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.2/yolov5s.pt to yolov5s.pt...
#
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
#   0%|          | 16.0k/14.1M [00:00<02:35, 95.3kB/s]
#   0%|          | 48.0k/14.1M [00:00<01:42, 144kB/s]
#   1%|          | 96.0k/14.1M [00:00<01:15, 196kB/s]
#   1%|1         | 160k/14.1M [00:00<00:58, 248kB/s]
#   1%|1         | 184k/14.1M [00:00<01:02, 234kB/s]
#   2%|1         | 240k/14.1M [00:01<00:50, 287kB/s]
#   2%|2         | 352k/14.1M [00:01<00:34, 418kB/s]
#   3%|3         | 448k/14.1M [00:01<00:26, 532kB/s]
#   3%|3         | 504k/14.1M [00:01<00:29, 490kB/s]
#   4%|3         | 560k/14.1M [00:01<00:32, 433kB/s]
#   4%|4         | 608k/14.1M [00:01<00:47, 298kB/s]
#   4%|4         | 648k/14.1M [00:02<00:50, 282kB/s]
#  99%|#########9| 14.0M/14.1M [02:29<00:00, 88.4kB/s]
# 100%|#########9| 14.1M/14.1M [02:29<00:00, 80.3kB/s]
# 100%|#########9| 14.1M/14.1M [02:30<00:00, 79.2kB/s]
# 100%|#########9| 14.1M/14.1M [02:30<00:00, 59.7kB/s]
# 100%|#########9| 14.1M/14.1M [02:30<00:00, 60.7kB/s]
# 100%|##########| 14.1M/14.1M [02:30<00:00, 98.3kB/s]
#
# Overriding model.yaml nc=80 with nc=10
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     40455  models.yolo.Detect                      [10, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# YOLOv5s summary: 214 layers, 7046599 parameters, 7046599 gradients
#
# Transferred 342/349 items from yolov5s.pt
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
#
# train: Scanning 'C:\Users\USER\T3Q_1_project\TrainingData\train' images and labels...:   0%|          | 0/80 [00:00<?, ?it/s]
# train: Scanning 'C:\Users\USER\T3Q_1_project\TrainingData\train' images and labels...0 found, 0 missing, 0 empty, 1 corrupt:   1%|1         | 1/80 [00:09<11:55,  9.05s/it]
# train: Scanning 'C:\Users\USER\T3Q_1_project\TrainingData\train' images and labels...0 found, 0 missing, 0 empty, 80 corrupt: 100%|##########| 80/80 [00:09<00:00,  8.82it/s]
# train: WARNING  C:\Users\USER\T3Q_1_project\TrainingData\TrainingData\data\change_img\V2F_HY_9148_20201221_111302_E_CH0_Seoul_Sun_Mainroad_Day_97331.png: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\USER\\T3Q_1_project\\TrainingData\\TrainingData\\data\\change_img\\V2F_HY_9148_20201221_111302_E_CH0_Seoul_Sun_Mainroad_Day_97331.png'
# train: WARNING  C:\Users\USER\T3Q_1_project\TrainingData\TrainingData\data\change_img\V2F_HY_9148_20201221_121331_E_CH1_Seoul_Sun_Mainroad_Day_54826.png: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\USER\\T3Q_1_project\\TrainingData\\TrainingData\\data\\change_img\\V2F_HY_9148_20201221_121331_E_CH1_Seoul_Sun_Mainroad_Day_54826.png'
# train: WARNING  C:\Users\USER\T3Q_1_project\TrainingData\TrainingData\data\change_img\V2F_HY_9287_20201221_111302_E_CH0_Seoul_Sun_Mainroad_Day_81019.png: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\USER\\T3Q_1_project\\TrainingData\\TrainingData\\data\\change_img\\V2F_HY_9287_20201221_111302_E_CH0_Seoul_Sun_Mainroad_Day_81019.png'
# train: WARNING  C:\Users\USER\T3Q_1_project\TrainingData\TrainingData\data\change_img\V2F_HY_9289_20201103_124453_N_CH2_Seoul_Sun_Mainroad_Day_60189.png: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\USER\\T3Q_1_project\\TrainingData\\TrainingData\\data\\change_img\\V2F_HY_9289_20201103_124453_N_CH2_Seoul_Sun_Mainroad_Day_60189.png'
# train: WARNING  C:\Users\USER\T3Q_1_project\TrainingData\TrainingData\data\change_img\V2F_HY_9289_20201221_141515_N_CH0_Seoul_Sun_Mainroad_Day_13404.png: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\USER\\T3Q_1_project\\TrainingData\\TrainingData\\data\\change_img\\V2F_HY_9289_20201221_141515_N_CH0_Seoul_Sun_Mainroad_Day_13404.png'
# train: WARNING  C:\Users\USER\T3Q_1_project\TrainingData\TrainingData\data\change_img\V2F_HY_9289_20210111_104944_N_CH2_Seoul_Cloud_Mainroad_Day_79837.png: ignoring corrupt image/label: [Errno 2] No such file or directory: 'C:\\Users\\USER\\T3Q_1_project\\TrainingData\\TrainingData\\data\\change_img\\V2F_HY_9289_20210111_104944_N_CH2_Seoul_Cloud_Mainroad_Day_79837.png'
# train: WARNING  No labels found in C:\Users\USER\T3Q_1_project\TrainingData\train.cache. See https://github.com/ultralytics/yolov5/wiki/Train-Custom-Data
# train: WARNING  Cache directory C:\Users\USER\T3Q_1_project\TrainingData is not writeable: [WinError 183]      : 'C:\\Users\\USER\\T3Q_1_project\\TrainingData\\train.cache.npy' -> 'C:\\Users\\USER\\T3Q_1_project\\TrainingData\\train.cache'
# Traceback (most recent call last):
#   File "C:\project\T3Q_projects_team_1\yolo_v5\yolov5-master\train.py", line 630, in <module>
#     main(opt)
#   File "C:\project\T3Q_projects_team_1\yolo_v5\yolov5-master\train.py", line 524, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "C:\project\T3Q_projects_team_1\yolo_v5\yolov5-master\train.py", line 185, in train
#     train_loader, dataset = create_dataloader(train_path,
#   File "C:\project\T3Q_projects_team_1\yolo_v5\yolov5-master\utils\dataloaders.py", line 124, in create_dataloader
#     dataset = LoadImagesAndLabels(
#   File "C:\project\T3Q_projects_team_1\yolo_v5\yolov5-master\utils\dataloaders.py", line 500, in __init__
#     assert nf > 0 or not augment, f'{prefix}No labels found in {cache_path}, can not start training. {HELP_URL}'
# AssertionError: train: No labels found in C:\Users\USER\T3Q_1_project\TrainingData\train.cache, can not start training. See https://github.com/ultralytics/yolov5/wiki/Train-Custom-Data
